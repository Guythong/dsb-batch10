# %% [markdown]
# <a href="https://colab.research.google.com/github/Guythong/dsb-batch10/blob/main/Mini_Project_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
import seaborn as sns
sns.set()

# %%
data = pd.read_csv('real_estate_price_size.csv')

# %%
data.describe()
# Out:
#                price         size
# count     100.000000   100.000000
# mean   292289.470160   853.024200
# std     77051.727525   297.941951
# min    154282.128000   479.750000
# 25%    234280.148000   643.330000
# 50%    280590.716000   696.405000
# 75%    335723.696000  1029.322500
# max    500681.128000  1842.510000

# %%
y = data['size']
x1 = data['price']

# %%
plt.scatter(x1,y)
plt.xlabel('Price',fontsize = 20)
plt.ylabel('Size' ,fontsize = 20)
plt.show()

# %%
x = sm.add_constant(x1)
result = sm.OLS(y,x).fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   size   R-squared:                       0.745
# Model:                            OLS   Adj. R-squared:                  0.742
# Method:                 Least Squares   F-statistic:                     285.9
# Date:                Tue, 22 Oct 2024   Prob (F-statistic):           8.13e-31
# Time:                        05:18:48   Log-Likelihood:                -642.81
# No. Observations:                 100   AIC:                             1290.
# Df Residuals:                      98   BIC:                             1295.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -122.3349     59.633     -2.051      0.043    -240.675      -3.994
# ...

# %%
plt.scatter(x1,y)
yhat = 	-122.3349+0.0033*x1
fig = plt.plot(x1,yhat, lw=4, c='orange', label ='regression line')
plt.xlabel('Price',fontsize = 20)
plt.ylabel('Size' ,fontsize = 20)
plt.show()
